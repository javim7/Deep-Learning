# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
iris = load_iris()

# %%
# Load data into a DataFrame
df = pd.DataFrame(iris.data, columns=iris.feature_names)
# Convert datatype to float
df = df.astype(float)
# append "target" and name it "label"
df['label'] = iris.target
# Use string label instead
df['label'] = df.label.replace(dict(enumerate(iris.target_names)))

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#          label
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]

# %%
# label -> one-hot encoding
label = pd.get_dummies(df['label'], prefix='label')
df = pd.concat([df, label], axis=1)
# drop old label
df.drop(['label'], axis=1, inplace=True)

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      label_setosa  label_versicolor  label_virginica
# 0               1                 0                0
# 1               1                 0                0
# 2               1                 0                0
# 3               1                 0                0
# 4               1                 0                0
# ..            ...               ...              ...
# 145             0                 0                1
# 146             0                 0                1
# 147             0                 0                1
# 148             0                 0                1
# 149             0                 0                1
#
# [150 rows x 7 columns]

# %%
# Creating X and y
X = df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']]
# Convert DataFrame into np array
X = np.asarray(X)
y = df[['label_setosa', 'label_versicolor', 'label_virginica']]
# Convert DataFrame into np array
y = np.asarray(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(
  X,
  y,
  test_size=0.20
)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization

# %%
batched_model = Sequential([
    Dense(64, input_shape=(4,), activation="relu"),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(3, activation='softmax')
]);

# %%
batched_model.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
batched_history =  batched_model.fit(
    X_train, 
    y_train, 
    epochs=200, 
    validation_split=0.25, 
    batch_size=40, 
    verbose=2
)
# Out:
# Epoch 1/200
# 3/3 - 2s - loss: 1.2827 - accuracy: 0.4556 - val_loss: 1.0640 - val_accuracy: 0.3667 - 2s/epoch - 519ms/step
# Epoch 2/200
# 3/3 - 0s - loss: 0.3168 - accuracy: 0.8889 - val_loss: 1.0580 - val_accuracy: 0.3667 - 33ms/epoch - 11ms/step
# Epoch 3/200
# 3/3 - 0s - loss: 0.1701 - accuracy: 0.9556 - val_loss: 1.0514 - val_accuracy: 0.3667 - 35ms/epoch - 12ms/step
# Epoch 4/200
# 3/3 - 0s - loss: 0.1177 - accuracy: 0.9889 - val_loss: 1.0363 - val_accuracy: 0.3667 - 35ms/epoch - 12ms/step
# Epoch 5/200
# 3/3 - 0s - loss: 0.0963 - accuracy: 0.9778 - val_loss: 1.0183 - val_accuracy: 0.3667 - 34ms/epoch - 11ms/step
# Epoch 6/200
# 3/3 - 0s - loss: 0.0682 - accuracy: 0.9889 - val_loss: 0.9996 - val_accuracy: 0.3667 - 37ms/epoch - 12ms/step
# Epoch 7/200
# 3/3 - 0s - loss: 0.0543 - accuracy: 1.0000 - val_loss: 0.9833 - val_accuracy: 0.4000 - 36ms/epoch - 12ms/step
# Epoch 8/200
# 3/3 - 0s - loss: 0.1226 - accuracy: 0.9556 - val_loss: 0.9708 - val_accuracy: 0.4000 - 38ms/epoch - 13ms/step
# Epoch 9/200
# 3/3 - 0s - loss: 0.0748 - accuracy: 0.9889 - val_loss: 0.9560 - val_accuracy: 0.4000 - 34ms/epoch - 11ms/step
# Epoch 10/200
# 3/3 - 0s - loss: 0.0563 - accuracy: 0.9778 - val_loss: 0.9399 - val_accuracy: 0.4667 - 36ms/epoch - 12ms/step
# Epoch 11/200
# 3/3 - 0s - loss: 0.0580 - accuracy: 0.9889 - val_loss: 0.9245 - val_accuracy: 0.5000 - 37ms/epoch - 12ms/step
# Epoch 12/200
# 3/3 - 0s - loss: 0.1015 - accuracy: 0.9556 - val_loss: 0.9078 - val_accuracy: 0.6000 - 40ms/epoch - 13ms/step
# Epoch 13/200
# 3/3 - 0s - loss: 0.0796 - accuracy: 0.9667 - val_loss: 0.8906 - val_accuracy: 0.7000 - 39ms/epoch - 13ms/step
# Epoch 14/200
# 3/3 - 0s - loss: 0.1700 - accuracy: 0.9667 - val_loss: 0.8770 - val_accuracy: 0.7333 - 40ms/epoch - 13ms/step
# Epoch 15/200
# 3/3 - 0s - loss: 0.0417 - accuracy: 0.9889 - val_loss: 0.8661 - val_accuracy: 0.7333 - 38ms/epoch - 13ms/step
# Epoch 16/200
# 3/3 - 0s - loss: 0.0254 - accuracy: 1.0000 - val_loss: 0.8554 - val_accuracy: 0.7333 - 35ms/epoch - 12ms/step
# Epoch 17/200
# 3/3 - 0s - loss: 0.0383 - accuracy: 1.0000 - val_loss: 0.8416 - val_accuracy: 0.7333 - 36ms/epoch - 12ms/step
# Epoch 18/200
# 3/3 - 0s - loss: 0.0771 - accuracy: 0.9778 - val_loss: 0.8236 - val_accuracy: 0.7333 - 36ms/epoch - 12ms/step
# Epoch 19/200
# 3/3 - 0s - loss: 0.0375 - accuracy: 0.9889 - val_loss: 0.8077 - val_accuracy: 0.7333 - 36ms/epoch - 12ms/step
# Epoch 20/200
# 3/3 - 0s - loss: 0.0667 - accuracy: 0.9889 - val_loss: 0.7913 - val_accuracy: 0.7333 - 36ms/epoch - 12ms/step
# Epoch 21/200
# 3/3 - 0s - loss: 0.0807 - accuracy: 0.9778 - val_loss: 0.7747 - val_accuracy: 0.7333 - 36ms/epoch - 12ms/step
# Epoch 22/200
# 3/3 - 0s - loss: 0.1552 - accuracy: 0.9556 - val_loss: 0.7598 - val_accuracy: 0.7333 - 36ms/epoch - 12ms/step
# Epoch 23/200
# 3/3 - 0s - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.7452 - val_accuracy: 0.7667 - 35ms/epoch - 12ms/step
# Epoch 24/200
# 3/3 - 0s - loss: 0.0432 - accuracy: 0.9889 - val_loss: 0.7295 - val_accuracy: 0.7667 - 37ms/epoch - 12ms/step
# Epoch 25/200
# 3/3 - 0s - loss: 0.0449 - accuracy: 1.0000 - val_loss: 0.7176 - val_accuracy: 0.8000 - 36ms/epoch - 12ms/step
# Epoch 26/200
# 3/3 - 0s - loss: 0.0331 - accuracy: 1.0000 - val_loss: 0.7036 - val_accuracy: 0.8333 - 38ms/epoch - 13ms/step
# Epoch 27/200
# 3/3 - 0s - loss: 0.2504 - accuracy: 0.9444 - val_loss: 0.6973 - val_accuracy: 0.9000 - 39ms/epoch - 13ms/step
# Epoch 28/200
# 3/3 - 0s - loss: 0.0285 - accuracy: 1.0000 - val_loss: 0.7058 - val_accuracy: 0.8667 - 40ms/epoch - 13ms/step
# Epoch 29/200
# 3/3 - 0s - loss: 0.0514 - accuracy: 0.9889 - val_loss: 0.7083 - val_accuracy: 0.8333 - 41ms/epoch - 14ms/step
# Epoch 30/200
# 3/3 - 0s - loss: 0.0314 - accuracy: 1.0000 - val_loss: 0.7067 - val_accuracy: 0.8333 - 39ms/epoch - 13ms/step
# Epoch 31/200
# 3/3 - 0s - loss: 0.1525 - accuracy: 0.9778 - val_loss: 0.7048 - val_accuracy: 0.8333 - 38ms/epoch - 13ms/step
# Epoch 32/200
# 3/3 - 0s - loss: 0.0489 - accuracy: 0.9889 - val_loss: 0.7093 - val_accuracy: 0.8000 - 36ms/epoch - 12ms/step
# Epoch 33/200
# 3/3 - 0s - loss: 0.0427 - accuracy: 1.0000 - val_loss: 0.7027 - val_accuracy: 0.8000 - 37ms/epoch - 12ms/step
# Epoch 34/200
# 3/3 - 0s - loss: 0.0481 - accuracy: 1.0000 - val_loss: 0.6871 - val_accuracy: 0.8333 - 37ms/epoch - 12ms/step
# Epoch 35/200
# 3/3 - 0s - loss: 0.0480 - accuracy: 0.9889 - val_loss: 0.6703 - val_accuracy: 0.8000 - 39ms/epoch - 13ms/step
# Epoch 36/200
# 3/3 - 0s - loss: 0.0468 - accuracy: 0.9889 - val_loss: 0.6478 - val_accuracy: 0.8333 - 38ms/epoch - 13ms/step
# Epoch 37/200
# 3/3 - 0s - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.6204 - val_accuracy: 0.8667 - 37ms/epoch - 12ms/step
# Epoch 38/200
# 3/3 - 0s - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.5930 - val_accuracy: 0.8667 - 38ms/epoch - 13ms/step
# Epoch 39/200
# 3/3 - 0s - loss: 0.0255 - accuracy: 1.0000 - val_loss: 0.5688 - val_accuracy: 0.9000 - 39ms/epoch - 13ms/step
# Epoch 40/200
# 3/3 - 0s - loss: 0.0746 - accuracy: 0.9778 - val_loss: 0.5418 - val_accuracy: 0.9000 - 39ms/epoch - 13ms/step
# Epoch 41/200
# 3/3 - 0s - loss: 0.0515 - accuracy: 0.9778 - val_loss: 0.5105 - val_accuracy: 0.9000 - 39ms/epoch - 13ms/step
# Epoch 42/200
# 3/3 - 0s - loss: 0.0451 - accuracy: 0.9778 - val_loss: 0.4865 - val_accuracy: 0.9000 - 39ms/epoch - 13ms/step
# Epoch 43/200
# 3/3 - 0s - loss: 0.0324 - accuracy: 1.0000 - val_loss: 0.4664 - val_accuracy: 0.9000 - 39ms/epoch - 13ms/step
# Epoch 44/200
# 3/3 - 0s - loss: 0.0618 - accuracy: 0.9889 - val_loss: 0.4476 - val_accuracy: 0.9333 - 37ms/epoch - 12ms/step
# Epoch 45/200
# 3/3 - 0s - loss: 0.0391 - accuracy: 0.9889 - val_loss: 0.4363 - val_accuracy: 0.9333 - 37ms/epoch - 12ms/step
# Epoch 46/200
# 3/3 - 0s - loss: 0.0458 - accuracy: 0.9889 - val_loss: 0.4308 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 47/200
# 3/3 - 0s - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.4299 - val_accuracy: 0.9000 - 40ms/epoch - 13ms/step
# Epoch 48/200
# 3/3 - 0s - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.4260 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 49/200
# 3/3 - 0s - loss: 0.0221 - accuracy: 1.0000 - val_loss: 0.4185 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 50/200
# 3/3 - 0s - loss: 0.0408 - accuracy: 0.9778 - val_loss: 0.4061 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 51/200
# 3/3 - 0s - loss: 0.0377 - accuracy: 1.0000 - val_loss: 0.3881 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step
# Epoch 52/200
# 3/3 - 0s - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.3685 - val_accuracy: 0.9333 - 43ms/epoch - 14ms/step
# Epoch 53/200
# 3/3 - 0s - loss: 0.0404 - accuracy: 1.0000 - val_loss: 0.3525 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 54/200
# 3/3 - 0s - loss: 0.0664 - accuracy: 0.9778 - val_loss: 0.3271 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 55/200
# 3/3 - 0s - loss: 0.0391 - accuracy: 0.9889 - val_loss: 0.3007 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 56/200
# 3/3 - 0s - loss: 0.0252 - accuracy: 0.9889 - val_loss: 0.2806 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 57/200
# 3/3 - 0s - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.2707 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 58/200
# 3/3 - 0s - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.2608 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 59/200
# 3/3 - 0s - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.2504 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 60/200
# 3/3 - 0s - loss: 0.0337 - accuracy: 0.9889 - val_loss: 0.2367 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 61/200
# 3/3 - 0s - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.2186 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 62/200
# 3/3 - 0s - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.2025 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 63/200
# 3/3 - 0s - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 1.0000 - 39ms/epoch - 13ms/step
# Epoch 64/200
# 3/3 - 0s - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.1819 - val_accuracy: 1.0000 - 40ms/epoch - 13ms/step
# Epoch 65/200
# 3/3 - 0s - loss: 0.0590 - accuracy: 0.9889 - val_loss: 0.1746 - val_accuracy: 1.0000 - 40ms/epoch - 13ms/step
# Epoch 66/200
# 3/3 - 0s - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.1644 - val_accuracy: 1.0000 - 42ms/epoch - 14ms/step
# Epoch 67/200
# 3/3 - 0s - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 1.0000 - 42ms/epoch - 14ms/step
# Epoch 68/200
# 3/3 - 0s - loss: 0.0319 - accuracy: 0.9778 - val_loss: 0.1360 - val_accuracy: 1.0000 - 44ms/epoch - 15ms/step
# Epoch 69/200
# 3/3 - 0s - loss: 0.1043 - accuracy: 0.9778 - val_loss: 0.1339 - val_accuracy: 1.0000 - 43ms/epoch - 14ms/step
# Epoch 70/200
# 3/3 - 0s - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 71/200
# 3/3 - 0s - loss: 0.0474 - accuracy: 0.9778 - val_loss: 0.1332 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 72/200
# 3/3 - 0s - loss: 0.0336 - accuracy: 0.9889 - val_loss: 0.1283 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 73/200
# 3/3 - 0s - loss: 0.0746 - accuracy: 0.9778 - val_loss: 0.1246 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 74/200
# 3/3 - 0s - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 75/200
# 3/3 - 0s - loss: 0.1258 - accuracy: 0.9667 - val_loss: 0.1144 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 76/200
# 3/3 - 0s - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.1022 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 77/200
# 3/3 - 0s - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.0984 - val_accuracy: 1.0000 - 42ms/epoch - 14ms/step
# Epoch 78/200
# 3/3 - 0s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.0974 - val_accuracy: 1.0000 - 42ms/epoch - 14ms/step
# Epoch 79/200
# 3/3 - 0s - loss: 0.0373 - accuracy: 0.9889 - val_loss: 0.0984 - val_accuracy: 1.0000 - 40ms/epoch - 13ms/step
# Epoch 80/200
# 3/3 - 0s - loss: 0.0314 - accuracy: 0.9889 - val_loss: 0.0954 - val_accuracy: 1.0000 - 41ms/epoch - 14ms/step
# Epoch 81/200
# 3/3 - 0s - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.0876 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 82/200
# 3/3 - 0s - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.0866 - val_accuracy: 0.9667 - 38ms/epoch - 13ms/step
# Epoch 83/200
# 3/3 - 0s - loss: 0.0738 - accuracy: 0.9778 - val_loss: 0.0817 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 84/200
# 3/3 - 0s - loss: 0.0220 - accuracy: 0.9889 - val_loss: 0.0790 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 85/200
# 3/3 - 0s - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.0791 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 86/200
# 3/3 - 0s - loss: 0.0814 - accuracy: 0.9778 - val_loss: 0.0804 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 87/200
# 3/3 - 0s - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0868 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 88/200
# 3/3 - 0s - loss: 0.0226 - accuracy: 0.9889 - val_loss: 0.0897 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 89/200
# 3/3 - 0s - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.0861 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 90/200
# 3/3 - 0s - loss: 0.1312 - accuracy: 0.9667 - val_loss: 0.0873 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 91/200
# 3/3 - 0s - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.1019 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 92/200
# 3/3 - 0s - loss: 0.0228 - accuracy: 0.9889 - val_loss: 0.1158 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 93/200
# 3/3 - 0s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.1270 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 94/200
# 3/3 - 0s - loss: 0.0232 - accuracy: 0.9889 - val_loss: 0.1323 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 95/200
# 3/3 - 0s - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.1309 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 96/200
# 3/3 - 0s - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.1251 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 97/200
# 3/3 - 0s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.1187 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 98/200
# 3/3 - 0s - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.1118 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 99/200
# 3/3 - 0s - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.1014 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 100/200
# 3/3 - 0s - loss: 0.0384 - accuracy: 0.9889 - val_loss: 0.0902 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 101/200
# 3/3 - 0s - loss: 0.0202 - accuracy: 0.9889 - val_loss: 0.0835 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 102/200
# 3/3 - 0s - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.0781 - val_accuracy: 0.9667 - 37ms/epoch - 12ms/step
# Epoch 103/200
# 3/3 - 0s - loss: 0.0399 - accuracy: 0.9889 - val_loss: 0.0688 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 104/200
# 3/3 - 0s - loss: 0.0220 - accuracy: 0.9889 - val_loss: 0.0519 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 105/200
# 3/3 - 0s - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 1.0000 - 42ms/epoch - 14ms/step
# Epoch 106/200
# 3/3 - 0s - loss: 0.0248 - accuracy: 0.9889 - val_loss: 0.0361 - val_accuracy: 1.0000 - 44ms/epoch - 15ms/step
# Epoch 107/200
# 3/3 - 0s - loss: 0.1195 - accuracy: 0.9667 - val_loss: 0.0333 - val_accuracy: 1.0000 - 42ms/epoch - 14ms/step
# Epoch 108/200
# 3/3 - 0s - loss: 0.0295 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 1.0000 - 41ms/epoch - 14ms/step
# Epoch 109/200
# 3/3 - 0s - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.0350 - val_accuracy: 1.0000 - 45ms/epoch - 15ms/step
# Epoch 110/200
# 3/3 - 0s - loss: 0.0343 - accuracy: 0.9889 - val_loss: 0.0490 - val_accuracy: 1.0000 - 48ms/epoch - 16ms/step
# Epoch 111/200
# 3/3 - 0s - loss: 0.0676 - accuracy: 0.9778 - val_loss: 0.1401 - val_accuracy: 0.9000 - 46ms/epoch - 15ms/step
# Epoch 112/200
# 3/3 - 0s - loss: 0.0345 - accuracy: 0.9889 - val_loss: 0.1971 - val_accuracy: 0.9000 - 44ms/epoch - 15ms/step
# Epoch 113/200
# 3/3 - 0s - loss: 0.0707 - accuracy: 0.9556 - val_loss: 0.1013 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 114/200
# 3/3 - 0s - loss: 0.0290 - accuracy: 0.9889 - val_loss: 0.0608 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 115/200
# 3/3 - 0s - loss: 0.0383 - accuracy: 0.9889 - val_loss: 0.0575 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 116/200
# 3/3 - 0s - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.0707 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 117/200
# 3/3 - 0s - loss: 0.0475 - accuracy: 0.9667 - val_loss: 0.0822 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 118/200
# 3/3 - 0s - loss: 0.0719 - accuracy: 0.9889 - val_loss: 0.0899 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 119/200
# 3/3 - 0s - loss: 0.0219 - accuracy: 0.9889 - val_loss: 0.0959 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 120/200
# 3/3 - 0s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 121/200
# 3/3 - 0s - loss: 0.0431 - accuracy: 0.9889 - val_loss: 0.1260 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 122/200
# 3/3 - 0s - loss: 0.0483 - accuracy: 0.9778 - val_loss: 0.1406 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 123/200
# 3/3 - 0s - loss: 0.0391 - accuracy: 0.9778 - val_loss: 0.1436 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 124/200
# 3/3 - 0s - loss: 0.0825 - accuracy: 0.9778 - val_loss: 0.1348 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 125/200
# 3/3 - 0s - loss: 0.0499 - accuracy: 0.9889 - val_loss: 0.1231 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 126/200
# 3/3 - 0s - loss: 0.0660 - accuracy: 0.9778 - val_loss: 0.1068 - val_accuracy: 0.9667 - 38ms/epoch - 13ms/step
# Epoch 127/200
# 3/3 - 0s - loss: 0.0527 - accuracy: 0.9778 - val_loss: 0.1055 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 128/200
# 3/3 - 0s - loss: 0.0195 - accuracy: 0.9889 - val_loss: 0.1048 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 129/200
# 3/3 - 0s - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.1084 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 130/200
# 3/3 - 0s - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.1109 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step
# Epoch 131/200
# 3/3 - 0s - loss: 0.0221 - accuracy: 1.0000 - val_loss: 0.1061 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step
# Epoch 132/200
# 3/3 - 0s - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0948 - val_accuracy: 0.9333 - 43ms/epoch - 14ms/step
# Epoch 133/200
# 3/3 - 0s - loss: 0.1679 - accuracy: 0.9556 - val_loss: 0.0847 - val_accuracy: 0.9333 - 43ms/epoch - 14ms/step
# Epoch 134/200
# 3/3 - 0s - loss: 0.0310 - accuracy: 0.9889 - val_loss: 0.1284 - val_accuracy: 0.9333 - 43ms/epoch - 14ms/step
# Epoch 135/200
# 3/3 - 0s - loss: 0.0201 - accuracy: 0.9889 - val_loss: 0.1830 - val_accuracy: 0.9333 - 44ms/epoch - 15ms/step
# Epoch 136/200
# 3/3 - 0s - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.1950 - val_accuracy: 0.9000 - 44ms/epoch - 15ms/step
# Epoch 137/200
# 3/3 - 0s - loss: 0.0503 - accuracy: 0.9778 - val_loss: 0.2187 - val_accuracy: 0.9000 - 42ms/epoch - 14ms/step
# Epoch 138/200
# 3/3 - 0s - loss: 0.0260 - accuracy: 0.9889 - val_loss: 0.2807 - val_accuracy: 0.8667 - 43ms/epoch - 14ms/step
# Epoch 139/200
# 3/3 - 0s - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.3055 - val_accuracy: 0.8667 - 42ms/epoch - 14ms/step
# Epoch 140/200
# 3/3 - 0s - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.3056 - val_accuracy: 0.8667 - 44ms/epoch - 15ms/step
# Epoch 141/200
# 3/3 - 0s - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.2955 - val_accuracy: 0.8667 - 44ms/epoch - 15ms/step
# Epoch 142/200
# 3/3 - 0s - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.2779 - val_accuracy: 0.8667 - 41ms/epoch - 14ms/step
# Epoch 143/200
# 3/3 - 0s - loss: 0.0224 - accuracy: 0.9889 - val_loss: 0.2633 - val_accuracy: 0.8667 - 43ms/epoch - 14ms/step
# Epoch 144/200
# 3/3 - 0s - loss: 0.0743 - accuracy: 0.9778 - val_loss: 0.2083 - val_accuracy: 0.9000 - 40ms/epoch - 13ms/step
# Epoch 145/200
# 3/3 - 0s - loss: 0.0280 - accuracy: 0.9889 - val_loss: 0.1389 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 146/200
# 3/3 - 0s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 147/200
# 3/3 - 0s - loss: 0.0474 - accuracy: 0.9889 - val_loss: 0.1143 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 148/200
# 3/3 - 0s - loss: 0.0253 - accuracy: 0.9889 - val_loss: 0.1513 - val_accuracy: 0.9000 - 42ms/epoch - 14ms/step
# Epoch 149/200
# 3/3 - 0s - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.2306 - val_accuracy: 0.8667 - 43ms/epoch - 14ms/step
# Epoch 150/200
# 3/3 - 0s - loss: 0.0228 - accuracy: 0.9889 - val_loss: 0.3100 - val_accuracy: 0.8667 - 39ms/epoch - 13ms/step
# Epoch 151/200
# 3/3 - 0s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.4352 - val_accuracy: 0.8667 - 42ms/epoch - 14ms/step
# Epoch 152/200
# 3/3 - 0s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.5470 - val_accuracy: 0.8333 - 40ms/epoch - 13ms/step
# Epoch 153/200
# 3/3 - 0s - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.6211 - val_accuracy: 0.8333 - 43ms/epoch - 14ms/step
# Epoch 154/200
# 3/3 - 0s - loss: 0.0183 - accuracy: 0.9889 - val_loss: 0.6704 - val_accuracy: 0.8333 - 42ms/epoch - 14ms/step
# Epoch 155/200
# 3/3 - 0s - loss: 0.0280 - accuracy: 1.0000 - val_loss: 0.6990 - val_accuracy: 0.8000 - 41ms/epoch - 14ms/step
# Epoch 156/200
# 3/3 - 0s - loss: 0.0389 - accuracy: 0.9889 - val_loss: 0.6117 - val_accuracy: 0.8333 - 42ms/epoch - 14ms/step
# Epoch 157/200
# 3/3 - 0s - loss: 0.0231 - accuracy: 0.9889 - val_loss: 0.5186 - val_accuracy: 0.8333 - 41ms/epoch - 14ms/step
# Epoch 158/200
# 3/3 - 0s - loss: 0.0335 - accuracy: 0.9778 - val_loss: 0.4336 - val_accuracy: 0.8667 - 40ms/epoch - 13ms/step
# Epoch 159/200
# 3/3 - 0s - loss: 0.1497 - accuracy: 0.9889 - val_loss: 0.3609 - val_accuracy: 0.8667 - 40ms/epoch - 13ms/step
# Epoch 160/200
# 3/3 - 0s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.3429 - val_accuracy: 0.8667 - 39ms/epoch - 13ms/step
# Epoch 161/200
# 3/3 - 0s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.3241 - val_accuracy: 0.8667 - 38ms/epoch - 13ms/step
# Epoch 162/200
# 3/3 - 0s - loss: 0.2592 - accuracy: 0.9667 - val_loss: 0.2831 - val_accuracy: 0.9000 - 40ms/epoch - 13ms/step
# Epoch 163/200
# 3/3 - 0s - loss: 0.0754 - accuracy: 0.9667 - val_loss: 0.1819 - val_accuracy: 0.9000 - 43ms/epoch - 14ms/step
# Epoch 164/200
# 3/3 - 0s - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9333 - 43ms/epoch - 14ms/step
# Epoch 165/200
# 3/3 - 0s - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.1061 - val_accuracy: 0.9333 - 44ms/epoch - 15ms/step
# Epoch 166/200
# 3/3 - 0s - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 167/200
# 3/3 - 0s - loss: 0.0369 - accuracy: 0.9778 - val_loss: 0.0630 - val_accuracy: 1.0000 - 45ms/epoch - 15ms/step
# Epoch 168/200
# 3/3 - 0s - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.0548 - val_accuracy: 1.0000 - 44ms/epoch - 15ms/step
# Epoch 169/200
# 3/3 - 0s - loss: 0.0475 - accuracy: 0.9778 - val_loss: 0.0600 - val_accuracy: 1.0000 - 40ms/epoch - 13ms/step
# Epoch 170/200
# 3/3 - 0s - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.0607 - val_accuracy: 1.0000 - 43ms/epoch - 14ms/step
# Epoch 171/200
# 3/3 - 0s - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.0715 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 172/200
# 3/3 - 0s - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.0978 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 173/200
# 3/3 - 0s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9333 - 44ms/epoch - 15ms/step
# Epoch 174/200
# 3/3 - 0s - loss: 0.0219 - accuracy: 1.0000 - val_loss: 0.1789 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step
# Epoch 175/200
# 3/3 - 0s - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9333 - 41ms/epoch - 14ms/step
# Epoch 176/200
# 3/3 - 0s - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.2442 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step
# Epoch 177/200
# 3/3 - 0s - loss: 0.0547 - accuracy: 0.9778 - val_loss: 0.2853 - val_accuracy: 0.9000 - 41ms/epoch - 14ms/step
# Epoch 178/200
# 3/3 - 0s - loss: 0.0713 - accuracy: 0.9667 - val_loss: 0.3505 - val_accuracy: 0.8667 - 43ms/epoch - 14ms/step
# Epoch 179/200
# 3/3 - 0s - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.3483 - val_accuracy: 0.8667 - 41ms/epoch - 14ms/step
# Epoch 180/200
# 3/3 - 0s - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.3480 - val_accuracy: 0.8667 - 38ms/epoch - 13ms/step
# Epoch 181/200
# 3/3 - 0s - loss: 0.1140 - accuracy: 0.9667 - val_loss: 0.2651 - val_accuracy: 0.8667 - 42ms/epoch - 14ms/step
# Epoch 182/200
# 3/3 - 0s - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 183/200
# 3/3 - 0s - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.0871 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 184/200
# 3/3 - 0s - loss: 0.0397 - accuracy: 0.9889 - val_loss: 0.0849 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 185/200
# 3/3 - 0s - loss: 0.0518 - accuracy: 0.9889 - val_loss: 0.1436 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 186/200
# 3/3 - 0s - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.1769 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 187/200
# 3/3 - 0s - loss: 0.0290 - accuracy: 0.9889 - val_loss: 0.1798 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 188/200
# 3/3 - 0s - loss: 0.0260 - accuracy: 1.0000 - val_loss: 0.1583 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 189/200
# 3/3 - 0s - loss: 0.0588 - accuracy: 0.9778 - val_loss: 0.1156 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 190/200
# 3/3 - 0s - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.0798 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 191/200
# 3/3 - 0s - loss: 0.0341 - accuracy: 0.9889 - val_loss: 0.0698 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 192/200
# 3/3 - 0s - loss: 0.0376 - accuracy: 0.9889 - val_loss: 0.0705 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 193/200
# 3/3 - 0s - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0955 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 194/200
# 3/3 - 0s - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 195/200
# 3/3 - 0s - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 0.9333 - 46ms/epoch - 15ms/step
# Epoch 196/200
# 3/3 - 0s - loss: 0.0368 - accuracy: 0.9778 - val_loss: 0.1874 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 197/200
# 3/3 - 0s - loss: 0.0139 - accuracy: 0.9889 - val_loss: 0.1955 - val_accuracy: 0.9333 - 46ms/epoch - 15ms/step
# Epoch 198/200
# 3/3 - 0s - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.2024 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step
# Epoch 199/200
# 3/3 - 0s - loss: 0.0285 - accuracy: 0.9889 - val_loss: 0.1901 - val_accuracy: 0.9000 - 46ms/epoch - 15ms/step
# Epoch 200/200
# 3/3 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.1986 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()

# %%
plot_metric(batched_history, 'accuracy')

# %%
plot_metric(batched_history, 'loss')

# %%
batched_model.evaluate(X_test, y_test, verbose=2)
# Out:
# 1/1 - 0s - loss: 0.1072 - accuracy: 0.9667 - 24ms/epoch - 24ms/step
# [0.10723955184221268, 0.9666666388511658]
